# %% [markdown]
# <a href="https://colab.research.google.com/github/dewshishir/problem/blob/main/assessment_2_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Create variables for your name, age, and favorite color, then print them with descriptive labels.

# %%
name = "Monowar"
age = 22
favorite_color = "Blue"
print("Name:", name)
print("Age:", age)
print("Favorite Color:", favorite_color)
# Out:
# Name: Monowar
# Age: 22
# Favorite Color: Blue

# %% [markdown]
# 2. Create one variable of each type and use the type() function to verify its type.

# %%
a = 10
b = 3.14
c = "Hello"
d = True
e = [1, 2, 3]
print(type(a), type(b), type(c), type(d), type(e))
# Out:
# <class 'int'> <class 'float'> <class 'str'> <class 'bool'> <class 'list'>

# %% [markdown]
# 3. Calculate the area and perimeter of a rectangle with length 7 and width 5.

# %%
length = 7
width = 5
area = length * width
perimeter = 2 * (length + width)
print(area, perimeter)
# Out:
# 35 24

# %% [markdown]
# 4. Create a list of 5 Bangladeshi foods, then access the first and last elements.

# %%
foods = ["Biryani", "Panta Bhat", "Fuchka", "Hilsa Fish", "Kacchi"]
print(foods[0], foods[-1])
# Out:
# Biryani Kacchi

# %% [markdown]
# 5. Create a list of 5 numbers, add a new number, remove one, and then sort the list.

# %%
nums = [10, 3, 5, 8, 2]
nums.append(7)
nums.remove(5)
nums.sort()
print(nums)
# Out:
# [2, 3, 7, 8, 10]

# %% [markdown]
# 6. Create a dictionary about yourself with at least 4 key-value pairs.

# %%
info = {"name": "Monowar", "age": 22, "city": "Dhaka", "hobby": "Coding"}
print(info)
# Out:
# {'name': 'Monowar', 'age': 22, 'city': 'Dhaka', 'hobby': 'Coding'}

# %% [markdown]
# 7. Create a tuple with the latitude and longitude of a famous place in Bangladesh.

# %%
location = (23.8103, 90.4125)
print(location)
# Out:
# (23.8103, 90.4125)

# %% [markdown]
# 8. Create two sets of colors and find their union and intersection.

# %%
set1 = {"red", "blue", "green"}
set2 = {"yellow", "blue", "black"}
print(set1.union(set2))
print(set1.intersection(set2))
# Out:
# {'red', 'yellow', 'green', 'black', 'blue'}
# {'blue'}

# %% [markdown]
# 9. Write a Python function that takes a string as input and prints the first and last character of the string.

# %%
def first_last(s):
    print(s[0], s[-1])

first_last("Bangladesh")
# Out:
# B h

# %% [markdown]
# 10. Write a Python function that takes a string and converts it to uppercase.

# %%
def to_upper(s):
    return s.upper()

print(to_upper("hello world"))
# Out:
# HELLO WORLD
